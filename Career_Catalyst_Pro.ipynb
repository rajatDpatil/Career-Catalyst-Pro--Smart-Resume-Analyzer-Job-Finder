# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatDpatil/Career-Catalyst-Pro--Smart-Resume-Analyzer-Job-Finder/blob/main/Career_Catalyst_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai gradio apify-client python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 65.4 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import drive, userdata
import gradio as gr

# %%
# Mount Google Drive to access your files
drive.mount('/content/drive')

# Create a project folder (optional but recommended)
# !mkdir -p "/content/drive/MyDrive/AI_Job_Recommender"

# Set working directory
os.chdir("/content/drive/MyDrive/AI_Job_Recommender")
# Out:
# Mounted at /content/drive

# %%
# Method 1: Using Colab Secrets (Recommended)
from google.colab import userdata

# %%
# Cell 1: API Key Setup
import os
from google.colab import userdata

try:
    # Try to get keys from Colab's secure storage
    GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
    APIFY_API_TOKEN = userdata.get('APIFY_API_TOKEN')
    print("✅ API keys loaded from Colab secrets")
except Exception as e:
    print("❌ Could not load from secrets. Please set your keys manually.")
    # Manual fallback - you'll need to enter your keys here
    GEMINI_API_KEY = "YOUR_GEMINI_API_KEY_HERE"  # REPLACE WITH YOUR ACTUAL KEY
    APIFY_API_TOKEN = "YOUR_APIFY_API_TOKEN_HERE"  # REPLACE WITH YOUR ACTUAL TOKEN

# Set environment variables
os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY
os.environ["APIFY_API_TOKEN"] = APIFY_API_TOKEN

print("Gemini Key length:", len(GEMINI_API_KEY) if GEMINI_API_KEY else "Missing")
print("Apify Token length:", len(APIFY_API_TOKEN) if APIFY_API_TOKEN else "Missing")
# Out:
# ✅ API keys loaded from Colab secrets
# Gemini Key length: 40
# Apify Token length: 46

# %%
#Gradio app..
